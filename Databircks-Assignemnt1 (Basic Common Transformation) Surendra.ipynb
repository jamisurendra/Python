# %% [markdown]
# <span style="color:orange">
#  <h2> Databircks-Assignemnt 1 (Basic Common Transformation)
# </span>
#   <h5>
#     <span style="color:red">
# <b>Author: Deepak Goyal <br>
#    <a> adeus.azurelib.com </a><br>
#    Email at: admin@azurelib.com
# </span>

# %%
#df = spark.read.csv('dbfs:/FileStore/shared_uploads/surijami@gmail.com/EmployeeData_HhTLiz9LdC-1.csv',header=True,inferSchema=True)
#df.display()

orderSchema = 'id integer ,first_name String ,last_name String ,email String ,gender String ,salary Integer ,creationdate Date ,bonus float'
                          
df1 = spark.read.load('dbfs:/FileStore/shared_uploads/surijami@gmail.com/EmployeeData_HhTLiz9LdC-1.csv',format="csv", header=True, schema=orderSchema)
df1.printSchema()
#df.schema
display(df)
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: integer (nullable = true)
#  |-- creationdate: date (nullable = true)
#  |-- bonus: float (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# <b>How many employees are in the input file?

# %%
# Write your code using the Spark Function          
#emp = df1.select('*').count().show()
emp = df1.count()
emp
# Out:
# 1000

# %% [markdown]
# <b> What is the average salary of all the employees?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import avg
avg_sal = df1.select(avg("salary")).show()
# Out:
# +------------------+
# |       avg(salary)|
# +------------------+
# |100011.38125665602|
# +------------------+

# %% [markdown]
# <b> How many male and female employees are there in the input file?

# %%
# Write your code using the Spark Function
#emp_fig = df1.groupBy("gender").sum('salary').show()
#emp_fig = df1.groupBy("gender").count()
#emp =emp_fig.filter("gender=='Male' or gender= 'Female'").show()

emp_fig = df1.groupBy("gender").count().filter("gender=='Male' or gender= 'Female'").show()
# Out:
# +------+-----+
# |gender|count|
# +------+-----+
# |Female|  501|
# |  Male|  471|
# +------+-----+

# %% [markdown]
# <b> Who is the employee with the highest salary?

# %%
# Write your code using the Spark Function
highest_sal = df1.select("id","salary").orderBy(col("salary").desc()).show(1)
#df1.sort("salary").show(5)

high = df1.select(max("salary")).show()
#high_sal = df1.filter("salary == df1.select(max(df1.salary)).show()")

#df1.select("id","salary").orderBy(col("salary").desc()).show(1)
# Out:
# +---+------+
# | id|salary|
# +---+------+
# |976|199846|
# +---+------+
# only showing top 1 row
#
# +-----------+
# |max(salary)|
# +-----------+
# |     199846|
# +-----------+

# %% [markdown]
# <b> What is the total bonus amount paid to all the employees?

# %%
# Write your code using the Spark Function
bonus_amt = df1.select(sum("bonus")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(bonus)</th></tr></thead><tbody><tr><td>4.250481240759277E7</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> How many employees were hired in the year 2020?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import desc, asc
emp_hire = df1.filter("year(creationDate) == '2020'").orderBy(col("salary").asc()).display()
#emp_hire = df1.filter("creationDate between '2020-01-01' and '2020-12-31'").orderBy(col("salary").asc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# d
# <b> Who are the top 5 employees with the highest salaries?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import desc

top5_sal = df1.select("*").orderBy(col("salary").desc()).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# d
# <b> What is the total salary paid to all male employees?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import sum,count

#df1.groupBy("gender").agg(sum("salary").alias("total_salary")).show
df1.filter("gender=='Male'").agg(sum("salary").alias("total_salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_salary</th></tr></thead><tbody><tr><td>44253777</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> Who is the employee with the highest bonus amount?

# %%
# Write your code using the Spark Function# Write your code using the Spark Function
from pyspark.sql.functions import max
#df1.select("id","bonus").agg(max("bonus")).display(1)

df1.orderBy(col("bonus").desc()).show(1)
# Out:
# +---+----------+---------+--------------------+------+------+------------+--------+
# | id|first_name|last_name|               email|gender|salary|creationdate|   bonus|
# +---+----------+---------+--------------------+------+------+------------+--------+
# |915|    Franni| Chessell|fchessellpe@meetu...|Female|101905|  1973-09-18|99993.16|
# +---+----------+---------+--------------------+------+------+------------+--------+
# only showing top 1 row

# %% [markdown]
# d
# <b> What is the earliest creation date of any employee in the input file?

# %%
# Write your code using the Spark Function
from pyspark.sql.functions import min

dat_df = df1.filter("creationdate is not null").orderBy(col("creationdate").asc()).show(1)
df2 =df1.select(min("creationdate")).show()
# Out:
# +---+----------+---------+--------------------+------+------+------------+-------+
# | id|first_name|last_name|               email|gender|salary|creationdate|  bonus|
# +---+----------+---------+--------------------+------+------+------------+-------+
# |697|    Norina|  Gotobed|ngotobedjc@illino...|Female|106852|  1900-07-08|5268.28|
# +---+----------+---------+--------------------+------+------+------------+-------+
# only showing top 1 row
#
# +-----------------+
# |min(creationdate)|
# +-----------------+
# |       1900-07-08|
# +-----------------+

# %% [markdown]
# d
# <b> How many employees have a salary greater than 100,000?

# %%
# Write your code using the Spark Function

df2 = df1.filter("salary >= 100000").orderBy(col("salary").asc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# d
# <b> Who is the female employee with the highest salary?

# %%
# Write your code using the Spark Function
df2 = df1.select("id","salary").filter("gender == 'Female'").orderBy(col("salary").desc()).limit(1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>salary</th></tr></thead><tbody><tr><td>849</td><td>198873</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> What is the total bonus amount paid to female employees?

# %%
# Write your code using the Spark Function
df2 = df1.filter("gender == 'Female'").groupBy("gender").sum("bonus").display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <command-3182359776596303>, line 2
#       1 # Write your code using the Spark Function
# ----> 2 df2 = df1.filter("gender == 'Female'").groupBy("gender").sum("bonus"/10^6).display()
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# d
# <b> How many employees have a salary between 50,000 and 75,000?

# %%
# Write your code using the Spark Function
df2 = df1.filter("salary between 50000 and 75000").orderBy(col("salary").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# d
# <b> Who are the top 10 employees with the highest bonuses?

# %%
# Write your code using the Spark Function

df2 =df1.select("id","bonus").orderBy(col("bonus").desc()).limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>bonus</th></tr></thead><tbody><tr><td>915</td><td>99993.16</td></tr><tr><td>830</td><td>99985.66</td></tr><tr><td>199</td><td>99932.43</td></tr><tr><td>537</td><td>99845.6</td></tr><tr><td>653</td><td>99650.89</td></tr><tr><td>896</td><td>99581.27</td></tr><tr><td>819</td><td>99046.27</td></tr><tr><td>382</td><td>99033.16</td></tr><tr><td>160</td><td>98721.92</td></tr><tr><td>635</td><td>98639.27</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> What is the latest creation date of any employee in the input file?

# %%
# Write your code using the Spark Function
#df2 = df1.select(max("creationdate")).show()
df2 = df1.select("id","creationdate").orderBy(col("creationdate").desc()).limit(1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>creationdate</th></tr></thead><tbody><tr><td>114</td><td>2023-03-24</td></tr></tbody></table></div>

# %% [markdown]
# d
# <b> How many employees have a salary less than 50,000?

# %%
# Write your code using the Spark Function
df2  = df1.filter("salary <= 50000").count()
df2
# Out:
# 234

# %% [markdown]
# d
# <b> Who are the top 3 employees with the lowest salaries?

# %%
# Write your code using the Spark Function
df2 = df1.select("*").filter("salary is not null").orderBy(col("salary").asc()).limit(3).show()
# Out:
# +---+----------+----------+--------------------+------+------+------------+--------+
# | id|first_name| last_name|               email|gender|salary|creationdate|   bonus|
# +---+----------+----------+--------------------+------+------+------------+--------+
# |809|  Hercules|Pollington|hpollingtonmg@chi...|  Male|   109|  1936-08-10| 57493.2|
# |381|     Olwen| O'Scanlon| ooscanlonak@usa.gov|Female|   184|  2017-10-11|22415.01|
# |542| Heriberto|      NULL| hsurmeyersf1@un.org|  Male|   479|        NULL|51871.41|
# +---+----------+----------+--------------------+------+------+------------+--------+

# %% [markdown]
# d
# <b> What is the average bonus amount paid to all employees?

# %%
# Write your code using the Spark Function

#df3 = df1.filter("bonus is not NULL")

df2 = df1.select(avg("bonus")).show()
# Out:
# +------------------+
# |        avg(bonus)|
# +------------------+
# |50965.002886801885|
# +------------------+

# %% [markdown]
# d
# <b> How many employees have a bonus greater than their salary?

# %%
# Write your code using the Spark Function

df2 = df1.where(col("salary") <= col("bonus")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
